# %%
# !pip install s3fs
# Out:
# Collecting s3fs
#   Using cached s3fs-0.4.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: botocore>=1.12.91 in /opt/conda/lib/python3.7/site-packages (from s3fs) (1.17.17)
# Requirement already satisfied: fsspec>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from s3fs) (0.6.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.7/site-packages (from botocore>=1.12.91->s3fs) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /opt/conda/lib/python3.7/site-packages (from botocore>=1.12.91->s3fs) (0.15.2)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /opt/conda/lib/python3.7/site-packages (from botocore>=1.12.91->s3fs) (1.25.8)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.7/site-packages (from botocore>=1.12.91->s3fs) (0.10.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.12.91->s3fs) (1.14.0)
# Installing collected packages: s3fs
# Successfully installed s3fs-0.4.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime as dt
import os
import boto3
from sklearn.metrics import mean_absolute_error
from io import StringIO
from sagemaker import get_execution_role
import s3fs

# %%
pop_df = pd.read_csv('stock_popularity.csv')

# %%
pop_df.set_index('symbol', inplace= True)

# %%
pop_df.head()
# Out:
#         users_holding        date
# symbol
# A              1180.0  2018-05-02
# A             11143.0  2018-05-03
# A             14099.0  2018-05-04
# A             14112.0  2018-05-05
# A             14112.0  2018-05-06

# %%
price_df = pd.read_csv("stock_prices_latest.csv")
price_df.set_index('symbol', inplace = True)
price_df.sort_values(by=['symbol','date'], inplace = True)
price_df.head()
# Out:
#               date   open   high    low  close  close_adjusted    volume  \
# symbol
# A       1999-11-18  45.50  50.00  40.00  44.00         29.6303  44739900
# A       1999-11-19  42.94  43.00  39.81  40.38         27.1926  10897100
# A       1999-11-22  41.31  44.00  40.06  44.00         29.6303   4705200
# A       1999-11-23  42.50  43.63  40.25  40.25         27.1050   4274400
# A       1999-11-24  40.13  41.94  40.00  41.06         27.6505   3464400
#
#         split_coefficient
# symbol
# A                     1.0
# A                     1.0
# A                     1.0
# A                     1.0
# A                     1.0

# %%
merged_df = pd.merge(pop_df, price_df, on=['symbol', 'date'])
merged_df.head()
# Out:
#         users_holding        date   open    high    low  close  \
# symbol
# A              1180.0  2018-05-02  66.00  66.860  65.77  65.91
# A             11143.0  2018-05-03  65.77  66.460  64.86  66.34
# A             14099.0  2018-05-04  66.03  67.250  65.54  67.00
# A             11718.0  2018-05-07  67.16  67.980  67.07  67.39
# A             13851.0  2018-05-08  67.08  67.435  66.84  67.37
#
#         close_adjusted   volume  split_coefficient
# symbol
# A                65.91  2240482                1.0
# A                66.34  2365851                1.0
# A                67.00  1331017                1.0
# A                67.39  1468735                1.0
# A                67.37  1916103                1.0

# %%
corr_df = merged_df.groupby('symbol')[['users_holding','close_adjusted']].corr().iloc[0::2,[-1]]
corr_df.head()
# Out:
#                       close_adjusted
# symbol
# A      users_holding        0.143153
# AA     users_holding       -0.806037
# AAL    users_holding       -0.641547
# AAMC   users_holding        0.438661
# AAME   users_holding       -0.255453

# %%
#Column has not been renamed, but close_adjusted essentially contains our correlations
high_corr_df = corr_df[(corr_df['close_adjusted'] >= 0.845) | (corr_df['close_adjusted'] <= -0.845)]
high_corr_df.info
# Out:
# <bound method DataFrame.info of                       close_adjusted
# symbol
# AAWW   users_holding       -0.873919
# ACER   users_holding       -0.854497
# ACMR   users_holding        0.869598
# AFH    users_holding       -0.908621
# AHPI   users_holding        0.955130
# ...                              ...
# VIIX   users_holding        0.912828
# VIIZ   users_holding       -0.912840
# YJ     users_holding       -0.855116
# YPF    users_holding       -0.873987
# ZEAL   users_holding        0.870370
#
# [115 rows x 1 columns]>

# %%
high_corr_df = high_corr_df.droplevel(None)

# %%
high_corr_df.index
# Out:
# Index(['AAWW', 'ACER', 'ACMR', 'AFH', 'AHPI', 'AMRH', 'ANDE', 'APLT', 'APT',
#        'ARCH',
#        ...
#        'TH', 'TLT', 'TRQ', 'TRXC', 'TUSK', 'VIIX', 'VIIZ', 'YJ', 'YPF',
#        'ZEAL'],
#       dtype='object', name='symbol', length=115)

# %%
merged_df.index
# Out:
# Index(['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A',
#        ...
#        'ZYXI', 'ZYXI', 'ZYXI', 'ZYXI', 'ZYXI', 'ZYXI', 'ZYXI', 'ZYXI', 'ZYXI',
#        'ZYXI'],
#       dtype='object', name='symbol', length=2491314)

# %%
keys = list(high_corr_df.index.values)
cleaned_df = merged_df[(merged_df.index).isin(high_corr_df.index)]

# %%
cleaned_df.info
# Out:
# <bound method DataFrame.info of         users_holding        date   open   high      low    close  \
# symbol
# AAWW            206.0  2018-05-02  63.90  63.90  62.1500  62.7500
# AAWW           2041.0  2018-05-03  63.30  68.00  63.3000  67.4000
# AAWW           2616.0  2018-05-04  67.50  67.70  65.0000  67.1500
# AAWW           2180.0  2018-05-07  67.25  67.85  67.0500  67.7500
# AAWW           2623.0  2018-05-08  67.40  68.55  67.2500  68.0500
# ...               ...         ...    ...    ...      ...      ...
# ZEAL           6290.0  2020-04-09  32.87  33.80  32.8700  33.4200
# ZEAL           6273.0  2020-04-13  33.06  33.06  32.1900  33.0000
# ZEAL           6306.0  2020-04-14  32.80  33.37  32.8000  33.3700
# ZEAL           6331.0  2020-04-15  31.39  31.79  30.9882  31.6148
# ZEAL           6322.0  2020-04-16  33.02  33.02  31.8200  33.0000
#
#         close_adjusted  volume  split_coefficient
# symbol
# AAWW           62.7500  397180                1.0
# AAWW           67.4000  983735                1.0
# AAWW           67.1500  308491                1.0
# AAWW           67.7500  172128                1.0
# AAWW           68.0500  395837                1.0
# ...                ...     ...                ...
# ZEAL           33.4200    4947                1.0
# ZEAL           33.0000    7631                1.0
# ZEAL           33.3700    4853                1.0
# ZEAL           31.6148    4792                1.0
# ZEAL           33.0000    2063                1.0
#
# [43061 rows x 9 columns]>

# %%
cleaned_df['Pop_EMA'] = cleaned_df.groupby('symbol')['users_holding'].transform(lambda x: x.ewm(span = 5).mean())
cleaned_df.head(20)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         users_holding        date   open    high     low  close  \
# symbol
# AAWW            206.0  2018-05-02  63.90  63.900  62.150  62.75
# AAWW           2041.0  2018-05-03  63.30  68.000  63.300  67.40
# AAWW           2616.0  2018-05-04  67.50  67.700  65.000  67.15
# AAWW           2180.0  2018-05-07  67.25  67.850  67.050  67.75
# AAWW           2623.0  2018-05-08  67.40  68.550  67.250  68.05
# AAWW           2629.0  2018-05-09  68.35  69.000  67.900  68.55
# AAWW           2591.0  2018-05-10  68.80  69.330  68.350  68.45
# AAWW           2603.0  2018-05-11  68.60  69.200  67.250  68.05
# AAWW           2613.0  2018-05-14  67.90  68.650  67.150  67.60
# AAWW           2591.0  2018-05-15  67.20  68.600  67.100  68.45
# AAWW           2613.0  2018-05-16  68.60  70.000  68.400  69.40
# AAWW           1778.0  2018-05-17  69.25  69.800  68.700  69.25
# AAWW           1915.0  2018-05-18  69.25  69.750  68.900  69.20
# AAWW           2725.0  2018-05-21  69.40  69.950  69.050  69.25
# AAWW           2790.0  2018-05-22  69.30  69.650  68.300  68.50
# AAWW           2814.0  2018-05-23  68.35  68.350  66.600  67.90
# AAWW           1994.0  2018-05-24  68.30  68.350  67.350  68.15
# AAWW           2828.0  2018-05-25  68.15  69.200  66.975  68.80
# AAWW           1534.0  2018-05-29  68.15  70.845  67.400  68.55
# AAWW            575.0  2018-05-30  69.05  69.950  68.600  68.80
#
#         close_adjusted  volume  split_coefficient      Pop_EMA
# symbol
# AAWW             62.75  397180                1.0   206.000000
# AAWW             67.40  983735                1.0  1307.000000
# AAWW             67.15  308491                1.0  1927.052632
# AAWW             67.75  172128                1.0  2032.123077
# AAWW             68.05  395837                1.0  2258.952607
# AAWW             68.55  206568                1.0  2394.172932
# AAWW             68.45  181232                1.0  2463.860612
# AAWW             68.05  134526                1.0  2512.123553
# AAWW             67.60  158448                1.0  2546.647071
# AAWW             68.45  218654                1.0  2561.692288
# AAWW             69.40  326141                1.0  2578.994894
# AAWW             69.25  198145                1.0  2309.922764
# AAWW             69.20  132104                1.0  2177.601948
# AAWW             69.25  152437                1.0  2360.695149
# AAWW             68.50  103741                1.0  2504.124309
# AAWW             67.90  118455                1.0  2607.573701
# AAWW             68.15  117426                1.0  2402.841339
# AAWW             68.80  192741                1.0  2544.656851
# AAWW             68.55  286351                1.0  2207.619199
# AAWW             68.80  200669                1.0  1663.249091

# %%
cleaned_df = cleaned_df[(cleaned_df != 0).all(1)]

# %%
compression_opts = dict(method='zip',
                        archive_name='stock_project.csv')  
cleaned_df.to_csv('dataScienceProject.zip', index=True, compression=compression_opts)

# %%
cleaned_df.index
# Out:
# Index(['AAWW', 'AAWW', 'AAWW', 'AAWW', 'AAWW', 'AAWW', 'AAWW', 'AAWW', 'AAWW',
#        'AAWW',
#        ...
#        'ZEAL', 'ZEAL', 'ZEAL', 'ZEAL', 'ZEAL', 'ZEAL', 'ZEAL', 'ZEAL', 'ZEAL',
#        'ZEAL'],
#       dtype='object', name='symbol', length=41564)

# %%
acb_df = df[df.symbol == 'ACB']
drop_cols = ['close_adjusted', 
            'volume', 'split_coefficient']
acb_df.drop(drop_cols, axis=1, inplace=True)
acb_df_ordered = acb_df.sort_values(by=['date'], ascending=False)
acb_df_ordered.head(10)

# %%
plt.figure(figsize=(18,10))
plt.plot(acb_df_ordered.date, acb_df_ordered.close)
plt.title('Closing price of ACB')
plt.ylabel('Closing price ($)')
plt.xlabel('Trading day')
plt.grid(False)
plt.show()

# %%
pop_df = pd.read_csv('ACB.csv', parse_dates=['timestamp'], index_col = ['timestamp'])
pop_df.head()

# %%
pop_df_daily = pop_df.resample('D').sum()
pop_df_daily.index.names = ['date']
pop_df_daily.head()

# %%
acb_df_ordered.index = pd.to_datetime(acb_df_ordered.date, format="%Y-%m-%d", errors='raise')
acb_df_ordered.head()

# %%
acb_df_ordered.drop('date', axis=1, inplace=True)

# %%
acb_df_ordered.head()

# %%
acb_df_ordered.index

# %%
pop_df_daily.index

# %%
combined_df = pd.merge(acb_df_ordered, pop_df_daily, on='date')
combined_df.head()

# %%
fig, ax1 = plt.subplots()
fig.set_figheight(12)
fig.set_figwidth(20)
ax2 = ax1.twinx()
x = combined_df.index

ax1.plot(x, combined_df.close, 'b-')
ax2.plot(x, combined_df.users_holding, 'r-')

ax1.set_xlabel('Trading day')
ax1.set_ylabel('Closing price ($)')
ax2.set_ylabel('Number of users holding (in millions)')
